# %%
import pandas as pd
import nltk
import json
from nltk.stem import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# Out:
# WARNING:tensorflow:From c:\Users\suimp\miniconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load data from JSON file
# change the path when you use it


json_file_path = r"C:\Users\suimp\OneDrive\Desktop\Duke University\Class\2023-Fall\IDS 703 Introduction to Natural Language Processing\Final Project\NLPFinalProject\data\train_formatted_output.json"

# %%
# Download WordNet resource
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\suimp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = []
with open(json_file_path, "r", encoding="utf-8") as file:
    for line in file:
        data.append(json.loads(line))

# %%
# Convert data to DataFrame
df = pd.DataFrame(data)

# Set display width to show entire content of the 'Answer' column
pd.set_option("display.max_colwidth", None)

# %%
df
# Out:
#                                                     Question  \
# 0                           How do I get help finding a job?
# 1                           How do I get help finding a job?
# 2                           How do I get help finding a job?
# 3                           How do I get help finding a job?
# 4                           How do I get help finding a job?
# ...                                                      ...
# 11317  Is it safe for me to manually replace my IUD at home?
# 11318  Is it safe for me to manually replace my IUD at home?
# 11319  Is it safe for me to manually replace my IUD at home?
# 11320  Is it safe for me to manually replace my IUD at home?
# 11321  Is it safe for me to manually replace my IUD at home?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Answer  \
# 0      If you are a current job seeker or participant, this fact sheet provides important information about mutual obligation requirements, appointments with your provider, and what to do if you are self-isolating:  Information for job seekers and participants  If you are participating in the ParentsNext program, this fact sheet provides important information about your activities and appointments.   Information for ParentsNext participants   ParentsNext participants Frequently Asked Questions   If you are a New Business Assistance with NEIS participant, these Frequently Asked Questions (FAQ) provides information about accessing the Coronavirus Supplement and what support is available during this time:  New Business Assistance with NEIS participants - Frequently Asked Questions  If you are a New Business Assistance with NEIS provider, these Frequently Asked Questions (FAQ) provides information about supporting NEIS participants during the Coronavirus situation.  New Business Assistance with NEIS providers – Frequently Asked Questions  *[NEIS]: New Enterprise Incentive Scheme
# 1      If you are a current job seeker or participant, this fact sheet provides important information about mutual obligation requirements, appointments with your provider, and what to do if you are self-isolating:  Information for job seekers and participants  If you are participating in the ParentsNext program, this fact sheet provides important information about your activities and appointments.   Information for ParentsNext participants   ParentsNext participants Frequently Asked Questions   If you are a New Business Assistance with NEIS participant, these Frequently Asked Questions (FAQ) provides information about accessing the Coronavirus Supplement and what support is available during this time:  New Business Assistance with NEIS participants - Frequently Asked Questions  If you are a New Business Assistance with NEIS provider, these Frequently Asked Questions (FAQ) provides information about supporting NEIS participants during the Coronavirus situation.  New Business Assistance with NEIS providers – Frequently Asked Questions  *[NEIS]: New Enterprise Incentive Scheme
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    In this rapidly changing jobs market the Australian Government is supporting businesses and those Australians looking for work. While many businesses have been adversely affected by COVID-19 and are reducing their workforces, there are some areas of the economy which have an increased demand for workers. This includes jobs in health and care sectors, transport and logistics, some areas of retail, mining and mining services, manufacturing, agriculture and government sectors, among others. The Jobs Hub helps you find advertised vacancies.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    In this rapidly changing jobs market the Australian Government is supporting businesses and those Australians looking for work. While many businesses have been adversely affected by COVID-19 and are reducing their workforces, there are some areas of the economy which have an increased demand for workers. This includes jobs in health and care sectors, transport and logistics, some areas of retail, mining and mining services, manufacturing, agriculture and government sectors, among others. The Jobs Hub helps you find advertised vacancies.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    To further assist job seekers to prepare for and move quickly back into work, the Morrison Government is also bringing forward the Employment Fund credit for the most job-ready job seekers to be available immediately, rather than after 13 weeks, which is currently the case. This change will apply to job seekers who commence in jobactive from 4 May 2020. The Employment Fund can be used by employment service providers to purchase work-related items including licenses, equipment, training or qualifications to ensure workers are prepared and able to take up critical roles in the economy.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 11317                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            If you do not want to become pregnant, you should start or continue to use your contraceptive method of choice. You may be able to access information and contraceptive services from a healthcare provider by phone or online. If you cannot access these services you may opt for a method that is available without a prescription (such as condoms, spermicides, pills, or emergency contraceptive pills) from a nearby pharmacy or drug shop.
# 11318                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              No. Disposable medical face masks are intended for a single use only. After use they should be removed using appropriate techniques (i.e. do no touch the front, remove by pulling the elastic ear straps or laces from behind) and disposed of immediately in an infectious waste bin with a lid, followed by hand hygiene. Click here for more information on using masks in the context of the nCoV outbreak.
# 11319                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              No. Disposable medical face masks are intended for a single use only. After use they should be removed using appropriate techniques (i.e. do no touch the front, remove by pulling the elastic ear straps or laces from behind) and disposed of immediately in an infectious waste bin with a lid, followed by hand hygiene. Click here for more information on using masks in the context of the nCoV outbreak.
# 11320                                                                                                                                                                                                              Removal of long acting methods such as implants or IUDs, after the recommended period of use (and routine follow up appointments) may not be prioritized by your country’s health system during this health emergency. Seek advice from your health provider. If you are experiencing side effects or desire urgent removal for other reasons, contact a provider to find out what options suit you best, and which are available and feasible. If, due to restrictions on movement due to the COVID-19 pandemic you cannot have your long acting method removed straight away, it is important to use another method of contraception to avoid pregnancy at this time. There are no medical problems caused by delaying removal of long acting methods such as implants or IUDs. Do not try to remove the contraception method yourself; wait until you are able to access health care from a trained provider.
# 11321                                                                                                                                                                                                              Removal of long acting methods such as implants or IUDs, after the recommended period of use (and routine follow up appointments) may not be prioritized by your country’s health system during this health emergency. Seek advice from your health provider. If you are experiencing side effects or desire urgent removal for other reasons, contact a provider to find out what options suit you best, and which are available and feasible. If, due to restrictions on movement due to the COVID-19 pandemic you cannot have your long acting method removed straight away, it is important to use another method of contraception to avoid pregnancy at this time. There are no medical problems caused by delaying removal of long acting methods such as implants or IUDs. Do not try to remove the contraception method yourself; wait until you are able to access health care from a trained provider.
#
#                   Rating  Score   Average
# 0              Excellent      4  2.333333
# 1      Could be Improved      2  2.333333
# 2              Excellent      4  3.500000
# 3              Excellent      4  3.500000
# 4                    Bad      1  2.700000
# ...                  ...    ...       ...
# 11317                Bad      1  2.500000
# 11318                Bad      1  1.666667
# 11319                Bad      1  1.666667
# 11320          Excellent      4  4.000000
# 11321          Excellent      4  4.000000
#
# [11322 rows x 5 columns]

# %%
# Stemming
stemmer = PorterStemmer()
df["Question"] = df["Question"].apply(
    lambda x: " ".join([stemmer.stem(word) for word in x.split()])
)
df["Answer"] = df["Answer"].apply(
    lambda x: " ".join([stemmer.stem(word) for word in x.split()])
)

# %%
default_filters = '!"#$%&()*+,-/:;<=>?@[\\]^_`{|}~\t\n'
filters = default_filters.replace(".", "")

# %%
tokenizer_all = Tokenizer()

# %%
tokenizer_all = Tokenizer(filters=filters)

# %%
combined_text = df["Question"] + " " + df["Answer"] + " " + df["Average"].astype(str)
tokenizer_all.fit_on_texts(combined_text)
total_words = len(tokenizer_all.word_index) + 1

# %%
word_index = tokenizer_all.word_index

# %%
# print word_index using dictionary
for word, index in tokenizer_all.word_index.items():
    print(f"Word: '{word}' --> Token: {index}")
# Out:
# Word: 'to' --> Token: 1
# Word: 'the' --> Token: 2
# Word: 'and' --> Token: 3
# Word: 'of' --> Token: 4
# Word: 'for' --> Token: 5
# Word: 'a' --> Token: 6
# Word: 'or' --> Token: 7
# Word: 'in' --> Token: 8
# Word: 'you' --> Token: 9
# Word: 'are' --> Token: 10
# Word: 'be' --> Token: 11
# Word: 'with' --> Token: 12
# Word: 'is' --> Token: 13
# Word: 'if' --> Token: 14
# Word: 'your' --> Token: 15
# Word: 'covid' --> Token: 16
# Word: '19' --> Token: 17
# Word: 'that' --> Token: 18
# Word: 'should' --> Token: 19
# Word: 'can' --> Token: 20
# Word: 'on' --> Token: 21
# Word: 'as' --> Token: 22
# Word: 'have' --> Token: 23
# Word: 'not' --> Token: 24
# Word: 'at' --> Token: 25
# Word: 'use' --> Token: 26
# Word: 'will' --> Token: 27
# Word: 'from' --> Token: 28
# Word: 'peopl' --> Token: 29
# Word: 'thi' --> Token: 30
# Word: 'who' --> Token: 31
# Word: 'their' --> Token: 32
# Word: 'provid' --> Token: 33
# Word: 'work' --> Token: 34
# Word: 'they' --> Token: 35
# Word: 'other' --> Token: 36
# Word: 'care' --> Token: 37
# Word: 'health' --> Token: 38
# Word: 'do' --> Token: 39
# Word: 'by' --> Token: 40
# Word: 'it' --> Token: 41
# Word: 'need' --> Token: 42
# Word: 'may' --> Token: 43
# Word: 'an' --> Token: 44
# Word: 'risk' --> Token: 45
# Word: 'home' --> Token: 46
# Word: 'what' --> Token: 47
# Word: 'how' --> Token: 48
# Word: 'contact' --> Token: 49
# Word: 'includ' --> Token: 50
# Word: 'clean' --> Token: 51
# Word: 'where' --> Token: 52
# Word: 'i' --> Token: 53
# Word: 'when' --> Token: 54
# Word: 'hand' --> Token: 55
# Word: 'person' --> Token: 56
# Word: 'coronaviru' --> Token: 57
# Word: 'about' --> Token: 58
# Word: 'support' --> Token: 59
# Word: 'protect' --> Token: 60
# Word: 'ha' --> Token: 61
# Word: 'more' --> Token: 62
# Word: 'children' --> Token: 63
# Word: 'such' --> Token: 64
# Word: 'dure' --> Token: 65
# Word: 'we' --> Token: 66
# Word: 'ani' --> Token: 67
# Word: 'school' --> Token: 68
# Word: 'help' --> Token: 69
# Word: 'all' --> Token: 70
# Word: 'servic' --> Token: 71
# Word: 'after' --> Token: 72
# Word: 'worker' --> Token: 73
# Word: 'take' --> Token: 74
# Word: 'face' --> Token: 75
# Word: 'get' --> Token: 76
# Word: 'guidanc' --> Token: 77
# Word: 'social' --> Token: 78
# Word: 'inform' --> Token: 79
# Word: 'these' --> Token: 80
# Word: 'follow' --> Token: 81
# Word: 'there' --> Token: 82
# Word: 'stay' --> Token: 83
# Word: 'test' --> Token: 84
# Word: 'make' --> Token: 85
# Word: 'local' --> Token: 86
# Word: 'symptom' --> Token: 87
# Word: 'continu' --> Token: 88
# Word: 'been' --> Token: 89
# Word: 'touch' --> Token: 90
# Word: 'requir' --> Token: 91
# Word: 'distanc' --> Token: 92
# Word: 'time' --> Token: 93
# Word: 'also' --> Token: 94
# Word: 'cover' --> Token: 95
# Word: 'them' --> Token: 96
# Word: 'those' --> Token: 97
# Word: 'set' --> Token: 98
# Word: 'spread' --> Token: 99
# Word: 'employ' --> Token: 100
# Word: 'medic' --> Token: 101
# Word: 'disinfect' --> Token: 102
# Word: 'keep' --> Token: 103
# Word: 'befor' --> Token: 104
# Word: '19.' --> Token: 105
# Word: 'child' --> Token: 106
# Word: 'staff' --> Token: 107
# Word: 'employe' --> Token: 108
# Word: 'my' --> Token: 109
# Word: 'public' --> Token: 110
# Word: 'safe' --> Token: 111
# Word: 'some' --> Token: 112
# Word: 'infect' --> Token: 113
# Word: 'sick' --> Token: 114
# Word: 'key' --> Token: 115
# Word: 'surfac' --> Token: 116
# Word: '.' --> Token: 117
# Word: 'reduc' --> Token: 118
# Word: 'wash' --> Token: 119
# Word: 'plan' --> Token: 120
# Word: 'consid' --> Token: 121
# Word: 'step' --> Token: 122
# Word: 'possibl' --> Token: 123
# Word: 'least' --> Token: 124
# Word: 'ensur' --> Token: 125
# Word: 'access' --> Token: 126
# Word: 'must' --> Token: 127
# Word: 'avail' --> Token: 128
# Word: 'but' --> Token: 129
# Word: 'out' --> Token: 130
# Word: 'prevent' --> Token: 131
# Word: 'commun' --> Token: 132
# Word: 'educ' --> Token: 133
# Word: 'payment' --> Token: 134
# Word: 'travel' --> Token: 135
# Word: 'busi' --> Token: 136
# Word: 'which' --> Token: 137
# Word: 'no' --> Token: 138
# Word: 'assess' --> Token: 139
# Word: 'one' --> Token: 140
# Word: 'like' --> Token: 141
# Word: 'famili' --> Token: 142
# Word: 'through' --> Token: 143
# Word: 'maintain' --> Token: 144
# Word: 'chang' --> Token: 145
# Word: 'avoid' --> Token: 146
# Word: 'household' --> Token: 147
# Word: 'patient' --> Token: 148
# Word: 'recommend' --> Token: 149
# Word: 'appli' --> Token: 150
# Word: 'wear' --> Token: 151
# Word: 'day' --> Token: 152
# Word: 'viru' --> Token: 153
# Word: 'place' --> Token: 154
# Word: 'age' --> Token: 155
# Word: 'isol' --> Token: 156
# Word: 'area' --> Token: 157
# Word: 'water' --> Token: 158
# Word: 'close' --> Token: 159
# Word: 'new' --> Token: 160
# Word: 'up' --> Token: 161
# Word: 'vulner' --> Token: 162
# Word: 'facil' --> Token: 163
# Word: 'see' --> Token: 164
# Word: 'while' --> Token: 165
# Word: 'visa' --> Token: 166
# Word: 'ppe' --> Token: 167
# Word: 'number' --> Token: 168
# Word: 'addit' --> Token: 169
# Word: 'food' --> Token: 170
# Word: 'import' --> Token: 171
# Word: 'activ' --> Token: 172
# Word: 'current' --> Token: 173
# Word: 'into' --> Token: 174
# Word: 'so' --> Token: 175
# Word: 'sever' --> Token: 176
# Word: 'self' --> Token: 177
# Word: 'onlin' --> Token: 178
# Word: 'than' --> Token: 179
# Word: 'year' --> Token: 180
# Word: 'stage' --> Token: 181
# Word: '2' --> Token: 182
# Word: 'example' --> Token: 183
# Word: 'healthcar' --> Token: 184
# Word: 'someon' --> Token: 185
# Word: 'cdc' --> Token: 186
# Word: 'way' --> Token: 187
# Word: 'learn' --> Token: 188
# Word: 'receiv' --> Token: 189
# Word: 'usual' --> Token: 190
# Word: 'soap' --> Token: 191
# Word: 'between' --> Token: 192
# Word: 'advic' --> Token: 193
# Word: 'state' --> Token: 194
# Word: 'condit' --> Token: 195
# Word: 'elig' --> Token: 196
# Word: 'fund' --> Token: 197
# Word: 'abl' --> Token: 198
# Word: 'workplac' --> Token: 199
# Word: 'ill' --> Token: 200
# Word: 'live' --> Token: 201
# Word: 'young' --> Token: 202
# Word: 'confirm' --> Token: 203
# Word: 'each' --> Token: 204
# Word: 'govern' --> Token: 205
# Word: 'limit' --> Token: 206
# Word: 'member' --> Token: 207
# Word: 'increas' --> Token: 208
# Word: 'manag' --> Token: 209
# Word: 'clinic' --> Token: 210
# Word: 'call' --> Token: 211
# Word: 'practic' --> Token: 212
# Word: 'return' --> Token: 213
# Word: 'allow' --> Token: 214
# Word: 'still' --> Token: 215
# Word: 'appropri' --> Token: 216
# Word: 'go' --> Token: 217
# Word: 'possible.' --> Token: 218
# Word: 'visit' --> Token: 219
# Word: 'under' --> Token: 220
# Word: 'student' --> Token: 221
# Word: 'earli' --> Token: 222
# Word: 'group' --> Token: 223
# Word: 'share' --> Token: 224
# Word: 'due' --> Token: 225
# Word: 'develop' --> Token: 226
# Word: 'author' --> Token: 227
# Word: 'control' --> Token: 228
# Word: 'mask' --> Token: 229
# Word: 'non' --> Token: 230
# Word: '–' --> Token: 231
# Word: 'cough' --> Token: 232
# Word: 'measur' --> Token: 233
# Word: 'safeti' --> Token: 234
# Word: 'individu' --> Token: 235
# Word: 'australian' --> Token: 236
# Word: 'resourc' --> Token: 237
# Word: 'leav' --> Token: 238
# Word: 'australia' --> Token: 239
# Word: 'case' --> Token: 240
# Word: 'ask' --> Token: 241
# Word: 'most' --> Token: 242
# Word: 'parent' --> Token: 243
# Word: 'find' --> Token: 244
# Word: 'arrang' --> Token: 245
# Word: 'encourag' --> Token: 246
# Word: 'cannot' --> Token: 247
# Word: 'could' --> Token: 248
# Word: 'meet' --> Token: 249
# Word: 'differ' --> Token: 250
# Word: 'higher' --> Token: 251
# Word: 'diseas' --> Token: 252
# Word: 'know' --> Token: 253
# Word: 'possible' --> Token: 254
# Word: '2020' --> Token: 255
# Word: 'further' --> Token: 256
# Word: 'onli' --> Token: 257
# Word: 'physic' --> Token: 258
# Word: 'high' --> Token: 259
# Word: 'nose' --> Token: 260
# Word: 'well' --> Token: 261
# Word: 'remain' --> Token: 262
# Word: 'whether' --> Token: 263
# Word: 'doe' --> Token: 264
# Word: 'critic' --> Token: 265
# Word: 'attend' --> Token: 266
# Word: 'respiratori' --> Token: 267
# Word: 'within' --> Token: 268
# Word: 'sure' --> Token: 269
# Word: 'same' --> Token: 270
# Word: 'train' --> Token: 271
# Word: 'put' --> Token: 272
# Word: 'dispos' --> Token: 273
# Word: 'remov' --> Token: 274
# Word: 'report' --> Token: 275
# Word: 'check' --> Token: 276
# Word: 'caus' --> Token: 277
# Word: 'might' --> Token: 278
# Word: 'becom' --> Token: 279
# Word: 'home.' --> Token: 280
# Word: 'hygien' --> Token: 281
# Word: 'period' --> Token: 282
# Word: 'prepar' --> Token: 283
# Word: 'then' --> Token: 284
# Word: 'against' --> Token: 285
# Word: 'evid' --> Token: 286
# Word: 'our' --> Token: 287
# Word: 'claim' --> Token: 288
# Word: 'suspect' --> Token: 289
# Word: 'cloth' --> Token: 290
# Word: 'transmiss' --> Token: 291
# Word: 'respons' --> Token: 292
# Word: 'process' --> Token: 293
# Word: 'alcohol' --> Token: 294
# Word: 'pay' --> Token: 295
# Word: 'base' --> Token: 296
# Word: 'open' --> Token: 297
# Word: 'over' --> Token: 298
# Word: 'emerg' --> Token: 299
# Word: 'becaus' --> Token: 300
# Word: 'frequent' --> Token: 301
# Word: 'free' --> Token: 302
# Word: 'coronavirus' --> Token: 303
# Word: 'equip' --> Token: 304
# Word: 'handl' --> Token: 305
# Word: 'good' --> Token: 306
# Word: 'bas' --> Token: 307
# Word: 'applic' --> Token: 308
# Word: 'deliveri' --> Token: 309
# Word: 'move' --> Token: 310
# Word: 'hour' --> Token: 311
# Word: '1' --> Token: 312
# Word: 'specif' --> Token: 313
# Word: '6' --> Token: 314
# Word: 'temporari' --> Token: 315
# Word: 'objective' --> Token: 316
# Word: '20' --> Token: 317
# Word: 'sanit' --> Token: 318
# Word: 'would' --> Token: 319
# Word: 'first' --> Token: 320
# Word: 'part' --> Token: 321
# Word: 'nation' --> Token: 322
# Word: 'needed' --> Token: 323
# Word: 'refer' --> Token: 324
# Word: '2.5' --> Token: 325
# Word: 'oper' --> Token: 326
# Word: 'however' --> Token: 327
# Word: 'room' --> Token: 328
# Word: 'transport' --> Token: 329
# Word: 'essenti' --> Token: 330
# Word: 'depart' --> Token: 331
# Word: 'glove' --> Token: 332
# Word: 'product' --> Token: 333
# Word: 'gener' --> Token: 334
# Word: 'item' --> Token: 335
# Word: 'feel' --> Token: 336
# Word: 'affect' --> Token: 337
# Word: 'system' --> Token: 338
# Word: 'carer' --> Token: 339
# Word: 'mental' --> Token: 340
# Word: 'expect' --> Token: 341
# Word: 'relat' --> Token: 342
# Word: 'mani' --> Token: 343
# Word: 'respir' --> Token: 344
# Word: 'until' --> Token: 345
# Word: 'cov' --> Token: 346
# Word: 'understand' --> Token: 347
# Word: 'read' --> Token: 348
# Word: 'treatment' --> Token: 349
# Word: 'best' --> Token: 350
# Word: 'effect' --> Token: 351
# Word: 'bodi' --> Token: 352
# Word: 'level' --> Token: 353
# Word: 'mean' --> Token: 354
# Word: 'job' --> Token: 355
# Word: 'outbreak' --> Token: 356
# Word: 'icon' --> Token: 357
# Word: 'you’r' --> Token: 358
# Word: 'potenti' --> Token: 359
# Word: 'https' --> Token: 360
# Word: 'restrict' --> Token: 361
# Word: 'order' --> Token: 362
# Word: 'back' --> Token: 363
# Word: 'event' --> Token: 364
# Word: 'action' --> Token: 365
# Word: 'normal' --> Token: 366
# Word: 'suppli' --> Token: 367
# Word: 'exposur' --> Token: 368
# Word: 'disabl' --> Token: 369
# Word: 'come' --> Token: 370
# Word: 'mouth' --> Token: 371
# Word: 'exampl' --> Token: 372
# Word: 'special' --> Token: 373
# Word: 'without' --> Token: 374
# Word: 'start' --> Token: 375
# Word: '14' --> Token: 376
# Word: 'detail' --> Token: 377
# Word: 'separ' --> Token: 378
# Word: 'end' --> Token: 379
# Word: 'had' --> Token: 380
# Word: 'routin' --> Token: 381
# Word: 'exist' --> Token: 382
# Word: '2019' --> Token: 383
# Word: 'scheme' --> Token: 384
# Word: 'older' --> Token: 385
# Word: 'website' --> Token: 386
# Word: 'phone' --> Token: 387
# Word: 'sars' --> Token: 388
# Word: 'account' --> Token: 389
# Word: 'registration' --> Token: 390
# Word: 'result' --> Token: 391
# Word: 'vehicl' --> Token: 392
# Word: 'even' --> Token: 393
# Word: 'space' --> Token: 394
# Word: 'circumst' --> Token: 395
# Word: 'guidelin' --> Token: 396
# Word: 'especi' --> Token: 397
# Word: '2.0' --> Token: 398
# Word: 'deliv' --> Token: 399
# Word: 'outsid' --> Token: 400
# Word: 'often' --> Token: 401
# Word: '3.0' --> Token: 402
# Word: 'yourself' --> Token: 403
# Word: '3' --> Token: 404
# Word: 'description' --> Token: 405
# Word: 'offer' --> Token: 406
# Word: 'away' --> Token: 407
# Word: 'direct' --> Token: 408
# Word: 'made' --> Token: 409
# Word: 'include' --> Token: 410
# Word: 'available' --> Token: 411
# Word: 'resid' --> Token: 412
# Word: 'anim' --> Token: 413
# Word: 'option' --> Token: 414
# Word: 'procedur' --> Token: 415
# Word: 'expos' --> Token: 416
# Word: 'reason' --> Token: 417
# Word: 'fever' --> Token: 418
# Word: 'alreadi' --> Token: 419
# Word: 'involv' --> Token: 420
# Word: 'hospit' --> Token: 421
# Word: 'date' --> Token: 422
# Word: 'identifi' --> Token: 423
# Word: 'enter' --> Token: 424
# Word: 'line' --> Token: 425
# Word: 'extrem' --> Token: 426
# Word: 'stages' --> Token: 427
# Word: 'veri' --> Token: 428
# Word: 'concern' --> Token: 429
# Word: 'monitor' --> Token: 430
# Word: 'short' --> Token: 431
# Word: 'childcar' --> Token: 432
# Word: 'section' --> Token: 433
# Word: 'laboratori' --> Token: 434
# Word: 'feet' --> Token: 435
# Word: 'assist' --> Token: 436
# Word: 'immedi' --> Token: 437
# Word: 'break' --> Token: 438
# Word: 'pandemic' --> Token: 439
# Word: 'except' --> Token: 440
# Word: 'incom' --> Token: 441
# Word: '60' --> Token: 442
# Word: 'contain' --> Token: 443
# Word: 'site' --> Token: 444
# Word: 'around' --> Token: 445
# Word: 'financi' --> Token: 446
# Word: 'advis' --> Token: 447
# Word: 'epa' --> Token: 448
# Word: 'approv' --> Token: 449
# Word: 'altern' --> Token: 450
# Word: 'anyon' --> Token: 451
# Word: 'us' --> Token: 452
# Word: 'law' --> Token: 453
# Word: 'decis' --> Token: 454
# Word: 'everyon' --> Token: 455
# Word: 'pandem' --> Token: 456
# Word: 'unabl' --> Token: 457
# Word: 'countri' --> Token: 458
# Word: 'e.g.' --> Token: 459
# Word: 'adult' --> Token: 460
# Word: 'underli' --> Token: 461
# Word: 'grant' --> Token: 462
# Word: 'now' --> Token: 463
# Word: 'determin' --> Token: 464
# Word: 'common' --> Token: 465
# Word: 'small' --> Token: 466
# Word: 'pleas' --> Token: 467
# Word: 'collect' --> Token: 468
# Word: 'much' --> Token: 469
# Word: 'seek' --> Token: 470
# Word: 'sign' --> Token: 471
# Word: 'right' --> Token: 472
# Word: 'full' --> Token: 473
# Word: 'type' --> Token: 474
# Word: '3.5' --> Token: 475
# Word: 'perform' --> Token: 476
# Word: 'centr' --> Token: 477
# Word: 'off' --> Token: 478
# Word: 'show' --> Token: 479
# Word: 'wa' --> Token: 480
# Word: 'seriou' --> Token: 481
# Word: 'symptoms.' --> Token: 482
# Word: 'sector' --> Token: 483
# Word: 'quarantin' --> Token: 484
# Word: 'impact' --> Token: 485
# Word: 'minimis' --> Token: 486
# Word: 'provis' --> Token: 487
# Word: 'anoth' --> Token: 488
# Word: 'territori' --> Token: 489
# Word: 'personnel' --> Token: 490
# Word: '4' --> Token: 491
# Word: 'relief' --> Token: 492
# Word: 'carri' --> Token: 493
# Word: 'remot' --> Token: 494
# Word: 'complet' --> Token: 495
# Word: 'were' --> Token: 496
# Word: 'per' --> Token: 497
# Word: 'chronic' --> Token: 498
# Word: 'implement' --> Token: 499
# Word: 'paid' --> Token: 500
# Word: '5' --> Token: 501
# Word: 'friend' --> Token: 502
# Word: 'look' --> Token: 503
# Word: 'depend' --> Token: 504
# Word: 'creat' --> Token: 505
# Word: 'regular' --> Token: 506
# Word: 'medicin' --> Token: 507
# Word: 'talk' --> Token: 508
# Word: 'shift' --> Token: 509
# Word: 'posit' --> Token: 510
# Word: 'nh' --> Token: 511
# Word: 'updat' --> Token: 512
# Word: 'necessari' --> Token: 513
# Word: 'studi' --> Token: 514
# Word: 'think' --> Token: 515
# Word: 'air' --> Token: 516
# Word: 'symptoms' --> Token: 517
# Word: 'contract' --> Token: 518
# Word: 'review' --> Token: 519
# Word: 'colleg' --> Token: 520
# Word: 'second' --> Token: 521
# Word: 'team' --> Token: 522
# Word: 'offic' --> Token: 523
# Word: 'don’t' --> Token: 524
# Word: 'stop' --> Token: 525
# Word: 'own' --> Token: 526
# Word: 'term' --> Token: 527
# Word: 'sneez' --> Token: 528
# Word: 'women' --> Token: 529
# Word: 'am' --> Token: 530
# Word: 'list' --> Token: 531
# Word: 'thing' --> Token: 532
# Word: 'unit' --> Token: 533
# Word: 'respond' --> Token: 534
# Word: 'droplet' --> Token: 535
# Word: '4.0' --> Token: 536
# Word: 'view' --> Token: 537
# Word: 'wast' --> Token: 538
# Word: 'tell' --> Token: 539
# Word: 'information' --> Token: 540
# Word: 'accord' --> Token: 541
# Word: 'form' --> Token: 542
# Word: 'consult' --> Token: 543
# Word: 'both' --> Token: 544
# Word: 'custom' --> Token: 545
# Word: 'associ' --> Token: 546
# Word: 'regularli' --> Token: 547
# Word: 'organis' --> Token: 548
# Word: 'tissu' --> Token: 549
# Word: 'data' --> Token: 550
# Word: 'people.' --> Token: 551
# Word: '2.25' --> Token: 552
# Word: 'regist' --> Token: 553
# Word: 'intern' --> Token: 554
# Word: 'workers' --> Token: 555
# Word: 'pregnant' --> Token: 556
# Word: 'situat' --> Token: 557
# Word: 'offici' --> Token: 558
# Word: 'treat' --> Token: 559
# Word: 'week' --> Token: 560
# Word: 'method' --> Token: 561
# Word: 'march' --> Token: 562
# Word: 'less' --> Token: 563
# Word: 'video' --> Token: 564
# Word: 'enabl' --> Token: 565
# Word: 'precaut' --> Token: 566
# Word: 'criteria' --> Token: 567
# Word: '2020.' --> Token: 568
# Word: 'virus.' --> Token: 569
# Word: 'point' --> Token: 570
# Word: 'particular' --> Token: 571
# Word: 'build' --> Token: 572
# Word: 'give' --> Token: 573
# Word: 'stress' --> Token: 574
# Word: 'cruis' --> Token: 575
# Word: 'tax' --> Token: 576
# Word: 'long' --> Token: 577
# Word: 'univers' --> Token: 578
# Word: 'instruct' --> Token: 579
# Word: 'note' --> Token: 580
# Word: 'standard' --> Token: 581
# Word: 'clear' --> Token: 582
# Word: 'credit' --> Token: 583
# Word: 'cost' --> Token: 584
# Word: 'crew' --> Token: 585
# Word: 'handwash' --> Token: 586
# Word: 'april' --> Token: 587
# Word: 'consider' --> Token: 588
# Word: 'screen' --> Token: 589
# Word: 'uk' --> Token: 590
# Word: '10' --> Token: 591
# Word: '1.5' --> Token: 592
# Word: 'particularli' --> Token: 593
# Word: 'known' --> Token: 594
# Word: 'door' --> Token: 595
# Word: 'others' --> Token: 596
# Word: 'rang' --> Token: 597
# Word: 'agent' --> Token: 598
# Word: 'guidance.' --> Token: 599
# Word: 'suggest' --> Token: 600
# Word: 'role' --> Token: 601
# Word: 'polici' --> Token: 602
# Word: 'object' --> Token: 603
# Word: 'connect' --> Token: 604
# Word: 'packag' --> Token: 605
# Word: 'secur' --> Token: 606
# Word: 'blood' --> Token: 607
# Word: 'sick.' --> Token: 608
# Word: 'tri' --> Token: 609
# Word: 'rate' --> Token: 610
# Word: 'arriv' --> Token: 611
# Word: 'longer' --> Token: 612
# Word: 'either' --> Token: 613
# Word: 'outdoor' --> Token: 614
# Word: 'contamin' --> Token: 615
# Word: 'design' --> Token: 616
# Word: 'send' --> Token: 617
# Word: 'learner' --> Token: 618
# Word: 'people' --> Token: 619
# Word: 'immun' --> Token: 620
# Word: 'email' --> Token: 621
# Word: 'benefit' --> Token: 622
# Word: 'visitor' --> Token: 623
# Word: 'issu' --> Token: 624
# Word: 'want' --> Token: 625
# Word: 'others.' --> Token: 626
# Word: 'ehc' --> Token: 627
# Word: 'pupil' --> Token: 628
# Word: 'time.' --> Token: 629
# Word: 'hous' --> Token: 630
# Word: 'wherev' --> Token: 631
# Word: 'amount' --> Token: 632
# Word: 'larg' --> Token: 633
# Word: 'cancel' --> Token: 634
# Word: 'coronavirus.' --> Token: 635
# Word: 'unless' --> Token: 636
# Word: '70' --> Token: 637
# Word: 'sit' --> Token: 638
# Word: 'flexibl' --> Token: 639
# Word: 'regul' --> Token: 640
# Word: 'appoint' --> Token: 641
# Word: 'partner' --> Token: 642
# Word: 'alway' --> Token: 643
# Word: 'agenc' --> Token: 644
# Word: 'extend' --> Token: 645
# Word: 'extra' --> Token: 646
# Word: 'use.' --> Token: 647
# Word: 'done' --> Token: 648
# Word: 'metr' --> Token: 649
# Word: 'available.' --> Token: 650
# Word: 'awar' --> Token: 651
# Word: 'relev' --> Token: 652
# Word: 'surfaces.' --> Token: 653
# Word: 'gather' --> Token: 654
# Word: 'manufacturer’' --> Token: 655
# Word: 'services' --> Token: 656
# Word: 'conduct' --> Token: 657
# Word: 'driver' --> Token: 658
# Word: 'foundat' --> Token: 659
# Word: 'properti' --> Token: 660
# Word: 'trade' --> Token: 661
# Word: 'taken' --> Token: 662
# Word: 'choos' --> Token: 663
# Word: 'eyes' --> Token: 664
# Word: 'sourc' --> Token: 665
# Word: 'via' --> Token: 666
# Word: 'dri' --> Token: 667
# Word: 'rel' --> Token: 668
# Word: 'given' --> Token: 669
# Word: 'them.' --> Token: 670
# Word: 'present' --> Token: 671
# Word: 'surgic' --> Token: 672
# Word: 'solut' --> Token: 673
# Word: 'meal' --> Token: 674
# Word: 'doctor' --> Token: 675
# Word: 'education' --> Token: 676
# Word: 'pass' --> Token: 677
# Word: 'materi' --> Token: 678
# Word: 'hiv' --> Token: 679
# Word: 'play' --> Token: 680
# Word: 'tb' --> Token: 681
# Word: 'everi' --> Token: 682
# Word: 'ventil' --> Token: 683
# Word: 'prescript' --> Token: 684
# Word: 'virus' --> Token: 685
# Word: 'question' --> Token: 686
# Word: 'care.' --> Token: 687
# Word: 'bleach' --> Token: 688
# Word: 'alcohol.' --> Token: 689
# Word: 'iconextern' --> Token: 690
# Word: 'proper' --> Token: 691
# Word: 'ship' --> Token: 692
# Word: 'babi' --> Token: 693
# Word: 'togeth' --> Token: 694
# Word: 'loan' --> Token: 695
# Word: '000' --> Token: 696
# Word: 'happen' --> Token: 697
# Word: 'organ' --> Token: 698
# Word: 'you.' --> Token: 699
# Word: 'breath' --> Token: 700
# Word: 'regard' --> Token: 701
# Word: 'sanitis' --> Token: 702
# Word: 'soon' --> Token: 703
# Word: 'mitig' --> Token: 704
# Word: 'funer' --> Token: 705
# Word: 'request' --> Token: 706
# Word: 'two' --> Token: 707
# Word: 'difficult' --> Token: 708
# Word: 'eat' --> Token: 709
# Word: 'june' --> Token: 710
# Word: 'bank' --> Token: 711
# Word: 'websit' --> Token: 712
# Word: 'recent' --> Token: 713
# Word: 'trust' --> Token: 714
# Word: 'passeng' --> Token: 715
# Word: 'letter' --> Token: 716
# Word: 'residenti' --> Token: 717
# Word: 'healthi' --> Token: 718
# Word: 'label' --> Token: 719
# Word: 'specimen' --> Token: 720
# Word: 'agre' --> Token: 721
# Word: 'themselv' --> Token: 722
# Word: 'releas' --> Token: 723
# Word: '1.0' --> Token: 724
# Word: 'notifi' --> Token: 725
# Word: 'pressur' --> Token: 726
# Word: 'areas.' --> Token: 727
# Word: 'schools' --> Token: 728
# Word: 'domest' --> Token: 729
# Word: 'discuss' --> Token: 730
# Word: 'fix' --> Token: 731
# Word: 'facemask' --> Token: 732
# Word: 'shop' --> Token: 733
# Word: 'approach' --> Token: 734
# Word: 'last' --> Token: 735
# Word: 'telehealth' --> Token: 736
# Word: 'work.' --> Token: 737
# Word: 'met' --> Token: 738
# Word: 'fee' --> Token: 739
# Word: 'publish' --> Token: 740
# Word: 'apprenticeship' --> Token: 741
# Word: 'consum' --> Token: 742
# Word: 'childhood' --> Token: 743
# Word: 'daili' --> Token: 744
# Word: 'gown' --> Token: 745
# Word: 'shield' --> Token: 746
# Word: 'month' --> Token: 747
# Word: 'vaccin' --> Token: 748
# Word: 'adjust' --> Token: 749
# Word: 'speak' --> Token: 750
# Word: 'internet' --> Token: 751
# Word: 'heart' --> Token: 752
# Word: '7' --> Token: 753
# Word: 'entitl' --> Token: 754
# Word: 'enrol' --> Token: 755
# Word: 'document' --> Token: 756
# Word: 'temperatur' --> Token: 757
# Word: 'viral' --> Token: 758
# Word: 'repres' --> Token: 759
# Word: 'infecti' --> Token: 760
# Word: 'asthma' --> Token: 761
# Word: 'record' --> Token: 762
# Word: 'store' --> Token: 763
# Word: 'lower' --> Token: 764
# Word: 'fit' --> Token: 765
# Word: 'down' --> Token: 766
# Word: 'privat' --> Token: 767
# Word: 'toilet' --> Token: 768
# Word: 'experi' --> Token: 769
# Word: '24' --> Token: 770
# Word: 'apart' --> Token: 771
# Word: 'mild' --> Token: 772
# Word: 'pet' --> Token: 773
# Word: 'compli' --> Token: 774
# Word: 'improv' --> Token: 775
# Word: 'eye' --> Token: 776
# Word: 'cdc’' --> Token: 777
# Word: 'next' --> Token: 778
# Word: 'areas' --> Token: 779
# Word: 'purpos' --> Token: 780
# Word: 'interim' --> Token: 781
# Word: 'teacher' --> Token: 782
# Word: 'link' --> Token: 783
# Word: '30' --> Token: 784
# Word: 'multipl' --> Token: 785
# Word: 'initi' --> Token: 786
# Word: 'distancing' --> Token: 787
# Word: 'onc' --> Token: 788
# Word: 'strategi' --> Token: 789
# Word: 'challeng' --> Token: 790
# Word: 'prior' --> Token: 791
# Word: 'distancing.' --> Token: 792
# Word: 'super' --> Token: 793
# Word: 'profession' --> Token: 794
# Word: 'exempt' --> Token: 795
# Word: 'worri' --> Token: 796
# Word: 'financ' --> Token: 797
# Word: 'workers.' --> Token: 798
# Word: 'let' --> Token: 799
# Word: 'circumstances.' --> Token: 800
# Word: 'certain' --> Token: 801
# Word: 'across' --> Token: 802
# Word: 'duti' --> Token: 803
# Word: 'bathroom' --> Token: 804
# Word: 'n95' --> Token: 805
# Word: 'wellb' --> Token: 806
# Word: 'suitabl' --> Token: 807
# Word: 'produc' --> Token: 808
# Word: 'therefor' --> Token: 809
# Word: 'ongo' --> Token: 810
# Word: 'digit' --> Token: 811
# Word: '50' --> Token: 812
# Word: 'conditions' --> Token: 813
# Word: 'community.' --> Token: 814
# Word: 'prioriti' --> Token: 815
# Word: 'infection.' --> Token: 816
# Word: '2.75' --> Token: 817
# Word: 'consist' --> Token: 818
# Word: 'community' --> Token: 819
# Word: 'directli' --> Token: 820
# Word: 'subsidi' --> Token: 821
# Word: 'surfaces' --> Token: 822
# Word: 'explain' --> Token: 823
# Word: 'fire' --> Token: 824
# Word: 'establish' --> Token: 825
# Word: '—' --> Token: 826
# Word: 'accept' --> Token: 827
# Word: 'exercis' --> Token: 828
# Word: 'signific' --> Token: 829
# Word: 'whi' --> Token: 830
# Word: 'particip' --> Token: 831
# Word: 'guid' --> Token: 832
# Word: 'decid' --> Token: 833
# Word: 'locat' --> Token: 834
# Word: 'service.' --> Token: 835
# Word: 'circumstances' --> Token: 836
# Word: '3.25' --> Token: 837
# Word: 'program' --> Token: 838
# Word: 'enforc' --> Token: 839
# Word: 'human' --> Token: 840
# Word: 'cours' --> Token: 841
# Word: '2m' --> Token: 842
# Word: 'outbreak.' --> Token: 843
# Word: '1.75' --> Token: 844
# Word: 'similar' --> Token: 845
# Word: 'wipe' --> Token: 846
# Word: 'industri' --> Token: 847
# Word: 'pandemic.' --> Token: 848
# Word: 'settings.' --> Token: 849
# Word: 'interact' --> Token: 850
# Word: 'experienc' --> Token: 851
# Word: 'it’' --> Token: 852
# Word: 'birth' --> Token: 853
# Word: 'administr' --> Token: 854
# Word: 'research' --> Token: 855
# Word: 'found' --> Token: 856
# Word: 'drug' --> Token: 857
# Word: 'polic' --> Token: 858
# Word: 'citizen' --> Token: 859
# Word: 'card' --> Token: 860
# Word: 'it.' --> Token: 861
# Word: 'wait' --> Token: 862
# Word: 'kill' --> Token: 863
# Word: '12' --> Token: 864
# Word: 'i'm' --> Token: 865
# Word: 'settings' --> Token: 866
# Word: 'minimum' --> Token: 867
# Word: 'sinc' --> Token: 868
# Word: 'select' --> Token: 869
# Word: 'skill' --> Token: 870
# Word: 'alloc' --> Token: 871
# Word: 'temporarili' --> Token: 872
# Word: 'abov' --> Token: 873
# Word: 'intend' --> Token: 874
# Word: 'rule' --> Token: 875
# Word: 'including' --> Token: 876
# Word: 'reserv' --> Token: 877
# Word: 'me' --> Token: 878
# Word: 'electron' --> Token: 879
# Word: 'gp' --> Token: 880
# Word: '2.6666666667' --> Token: 881
# Word: 'hold' --> Token: 882
# Word: 'wish' --> Token: 883
# Word: 're' --> Token: 884
# Word: 'fac' --> Token: 885
# Word: 'legal' --> Token: 886
# Word: 'entri' --> Token: 887
# Word: 'seconds.' --> Token: 888
# Word: 'workplace.' --> Token: 889
# Word: 'far' --> Token: 890
# Word: 'c' --> Token: 891
# Word: 'england' --> Token: 892
# Word: 'rather' --> Token: 893
# Word: 'just' --> Token: 894
# Word: 'transit' --> Token: 895
# Word: 'delay' --> Token: 896
# Word: 'unwel' --> Token: 897
# Word: 'whenev' --> Token: 898
# Word: 'barrier' --> Token: 899
# Word: 'advanc' --> Token: 900
# Word: 'flow' --> Token: 901
# Word: 'greater' --> Token: 902
# Word: 'environ' --> Token: 903
# Word: 'car' --> Token: 904
# Word: 'among' --> Token: 905
# Word: 'few' --> Token: 906
# Word: 'contracept' --> Token: 907
# Word: 'website.' --> Token: 908
# Word: 'transfer' --> Token: 909
# Word: 'below' --> Token: 910
# Word: 'practis' --> Token: 911
# Word: 'refund' --> Token: 912
# Word: 'coughing' --> Token: 913
# Word: 'following' --> Token: 914
# Word: '16' --> Token: 915
# Word: 'address' --> Token: 916
# Word: 'act' --> Token: 917
# Word: 'pharmaci' --> Token: 918
# Word: 'mobil' --> Token: 919
# Word: 'voucher' --> Token: 920
# Word: 'exam' --> Token: 921
# Word: 'calcul' --> Token: 922
# Word: 'singl' --> Token: 923
# Word: 'day.' --> Token: 924
# Word: 'low' --> Token: 925
# Word: 'holder' --> Token: 926
# Word: 'place.' --> Token: 927
# Word: 'mind' --> Token: 928
# Word: 'fact' --> Token: 929
# Word: 'post' --> Token: 930
# Word: 'services.' --> Token: 931
# Word: '2.8333333333' --> Token: 932
# Word: 'days.' --> Token: 933
# Word: 'sexual' --> Token: 934
# Word: 'worn' --> Token: 935
# Word: 'paper' --> Token: 936
# Word: 'providers' --> Token: 937
# Word: 'submit' --> Token: 938
# Word: 'difficulti' --> Token: 939
# Word: 'engag' --> Token: 940
# Word: 'love' --> Token: 941
# Word: 'evalu' --> Token: 942
# Word: 'run' --> Token: 943
# Word: 'hygiene' --> Token: 944
# Word: 'spend' --> Token: 945
# Word: 'light' --> Token: 946
# Word: 'sport' --> Token: 947
# Word: 'illness' --> Token: 948
# Word: 'disease' --> Token: 949
# Word: 'apprentic' --> Token: 950
# Word: 'board' --> Token: 951
# Word: 'supplementari' --> Token: 952
# Word: 'otherwis' --> Token: 953
# Word: 'handles' --> Token: 954
# Word: 'kept' --> Token: 955
# Word: 'workplace' --> Token: 956
# Word: 'correct' --> Token: 957
# Word: '2.3333333333' --> Token: 958
# Word: '2.1666666667' --> Token: 959
# Word: 'charg' --> Token: 960
# Word: 'jobkeep' --> Token: 961
# Word: 'visibl' --> Token: 962
# Word: 'sampl' --> Token: 963
# Word: 'provider.' --> Token: 964
# Word: 'alert' --> Token: 965
# Word: 'slow' --> Token: 966
# Word: 'online.' --> Token: 967
# Word: 'rooms' --> Token: 968
# Word: 'hepat' --> Token: 969
# Word: 'devic' --> Token: 970
# Word: 'season' --> Token: 971
# Word: 'novel' --> Token: 972
# Word: 'period.' --> Token: 973
# Word: 'facility' --> Token: 974
# Word: 'commerci' --> Token: 975
# Word: 'institut' --> Token: 976
# Word: 'media' --> Token: 977
# Word: 'detect' --> Token: 978
# Word: '3.75' --> Token: 979
# Word: 'illness.' --> Token: 980
# Word: 'download' --> Token: 981
# Word: 'hands.' --> Token: 982
# Word: 'effort' --> Token: 983
# Word: 'employees.' --> Token: 984
# Word: 'facility.' --> Token: 985
# Word: 'book' --> Token: 986
# Word: 'neg' --> Token: 987
# Word: 'groceri' --> Token: 988
# Word: 'statutori' --> Token: 989
# Word: 'tip' --> Token: 990
# Word: 'appear' --> Token: 991
# Word: 'progress' --> Token: 992
# Word: 'virtual' --> Token: 993
# Word: 'disease.' --> Token: 994
# Word: 'replac' --> Token: 995
# Word: 'accommod' --> Token: 996
# Word: 'minim' --> Token: 997
# Word: 'dismiss' --> Token: 998
# Word: 'rest' --> Token: 999
# Word: 'everyday' --> Token: 1000
# Word: 'australia.' --> Token: 1001
# Word: 'independ' --> Token: 1002
# Word: 'gloves' --> Token: 1003
# Word: 'facilities' --> Token: 1004
# Word: 'conditions.' --> Token: 1005
# Word: 'laundri' --> Token: 1006
# Word: 'balanc' --> Token: 1007
# Word: 'blow' --> Token: 1008
# Word: 'transmit' --> Token: 1009
# Word: 'hmrc' --> Token: 1010
# Word: 'bring' --> Token: 1011
# Word: 'name' --> Token: 1012
# Word: 'aim' --> Token: 1013
# Word: 'instead' --> Token: 1014
# Word: 'you’ll' --> Token: 1015
# Word: 'teach' --> Token: 1016
# Word: 'properli' --> Token: 1017
# Word: 'better' --> Token: 1018
# Word: 'children’' --> Token: 1019
# Word: 'facilities.' --> Token: 1020
# Word: 'enough' --> Token: 1021
# Word: 'workstat' --> Token: 1022
# Word: 'esfa' --> Token: 1023
# Word: 'germ' --> Token: 1024
# Word: 'here' --> Token: 1025
# Word: 'begin' --> Token: 1026
# Word: 'abus' --> Token: 1027
# Word: 'upon' --> Token: 1028
# Word: 'die' --> Token: 1029
# Word: 'announc' --> Token: 1030
# Word: 'perman' --> Token: 1031
# Word: 'cope' --> Token: 1032
# Word: 'believ' --> Token: 1033
# Word: 'whilst' --> Token: 1034
# Word: 'math' --> Token: 1035
# Word: 'equipment' --> Token: 1036
# Word: 'payment.' --> Token: 1037
# Word: 'permit' --> Token: 1038
# Word: 'practition' --> Token: 1039
# Word: 'ppe.' --> Token: 1040
# Word: 'throughout' --> Token: 1041
# Word: 'yes.' --> Token: 1042
# Word: 'helplin' --> Token: 1043
# Word: 'covidsaf' --> Token: 1044
# Word: 'year.' --> Token: 1045
# Word: 'online' --> Token: 1046
# Word: 'lung' --> Token: 1047
# Word: 'yet' --> Token: 1048
# Word: 'factor' --> Token: 1049
# Word: 'visa.' --> Token: 1050
# Word: 'loss' --> Token: 1051
# Word: 'reopen' --> Token: 1052
# Word: 'programm' --> Token: 1053
# Word: 'required' --> Token: 1054
# Word: 'cases' --> Token: 1055
# Word: 'measures.' --> Token: 1056
# Word: 'valid' --> Token: 1057
# Word: 'recognis' --> Token: 1058
# Word: 'buy' --> Token: 1059
# Word: 'b' --> Token: 1060
# Word: 'lab' --> Token: 1061
# Word: 'sell' --> Token: 1062
# Word: 'introduc' --> Token: 1063
# Word: 'life' --> Token: 1064
# Word: 'app' --> Token: 1065
# Word: 'window' --> Token: 1066
# Word: 'durat' --> Token: 1067
# Word: 'schedul' --> Token: 1068
# Word: 'liver' --> Token: 1069
# Word: 'mis' --> Token: 1070
# Word: 'count' --> Token: 1071
# Word: 'religi' --> Token: 1072
# Word: 'sent' --> Token: 1073
# Word: 'notic' --> Token: 1074
# Word: 'environment' --> Token: 1075
# Word: 'so.' --> Token: 1076
# Word: 'airlin' --> Token: 1077
# Word: 'crowd' --> Token: 1078
# Word: '•' --> Token: 1079
# Word: 'signag' --> Token: 1080
# Word: 'user' --> Token: 1081
# Word: 'discontinu' --> Token: 1082
# Word: 'indic' --> Token: 1083
# Word: '8' --> Token: 1084
# Word: 'major' --> Token: 1085
# Word: 'expir' --> Token: 1086
# Word: 'session' --> Token: 1087
# Word: 'aerosol' --> Token: 1088
# Word: 'malaria' --> Token: 1089
# Word: 'catch' --> Token: 1090
# Word: 'spray' --> Token: 1091
# Word: 'although' --> Token: 1092
# Word: 'furlough' --> Token: 1093
# Word: 'total' --> Token: 1094
# Word: 'agreement' --> Token: 1095
# Word: 'infection' --> Token: 1096
# Word: 'cancer' --> Token: 1097
# Word: 'pick' --> Token: 1098
# Word: 'pre' --> Token: 1099
# Word: 'parti' --> Token: 1100
# Word: 'information.' --> Token: 1101
# Word: 'deterg' --> Token: 1102
# Word: 'thoroughli' --> Token: 1103
# Word: 'network' --> Token: 1104
# Word: 'side' --> Token: 1105
# Word: 'filter' --> Token: 1106
# Word: 'ncov' --> Token: 1107
# Word: 'qualifi' --> Token: 1108
# Word: 'world' --> Token: 1109
# Word: 'days' --> Token: 1110
# Word: 'cash' --> Token: 1111
# Word: 'transmission' --> Token: 1112
# Word: 'antibodi' --> Token: 1113
# Word: 'thought' --> Token: 1114
# Word: 'region' --> Token: 1115
# Word: 'extern' --> Token: 1116
# Word: 'toilets' --> Token: 1117
# Word: 'employer' --> Token: 1118
# Word: 'remind' --> Token: 1119
# Word: 'child’' --> Token: 1120
# Word: 'readili' --> Token: 1121
# Word: 'infant' --> Token: 1122
# Word: 'vulnerable' --> Token: 1123
# Word: 'three' --> Token: 1124
# Word: 'insur' --> Token: 1125
# Word: 'compani' --> Token: 1126
# Word: 'park' --> Token: 1127
# Word: 'abil' --> Token: 1128
# Word: 'lender' --> Token: 1129
# Word: 'pattern' --> Token: 1130
# Word: 'moder' --> Token: 1131
# Word: 'homeless' --> Token: 1132
# Word: 'primari' --> Token: 1133
# Word: 'risk.' --> Token: 1134
# Word: 'wearer' --> Token: 1135
# Word: 'problem' --> Token: 1136
# Word: 'icon.' --> Token: 1137
# Word: 'holiday' --> Token: 1138
# Word: 'stream' --> Token: 1139
# Word: 'suffici' --> Token: 1140
# Word: 'subject' --> Token: 1141
# Word: 'class' --> Token: 1142
# Word: 'needed.' --> Token: 1143
# Word: 'content' --> Token: 1144
# Word: 'stagger' --> Token: 1145
# Word: 'oversea' --> Token: 1146
# Word: 'rememb' --> Token: 1147
# Word: 'principl' --> Token: 1148
# Word: 'towel' --> Token: 1149
# Word: 'rout' --> Token: 1150
# Word: 'safeguard' --> Token: 1151
# Word: 'racial' --> Token: 1152
# Word: 'lead' --> Token: 1153
# Word: 'frequenc' --> Token: 1154
# Word: 'past' --> Token: 1155
# Word: 'superannu' --> Token: 1156
# Word: 'toward' --> Token: 1157
# Word: 'death' --> Token: 1158
# Word: 'task' --> Token: 1159
# Word: 'demand' --> Token: 1160
# Word: 'no.' --> Token: 1161
# Word: 'subclass' --> Token: 1162
# Word: 'text' --> Token: 1163
# Word: 'certif' --> Token: 1164
# Word: 'appropriate.' --> Token: 1165
# Word: 'materials' --> Token: 1166
# Word: 'gcse' --> Token: 1167
# Word: 'oblig' --> Token: 1168
# Word: 'undertak' --> Token: 1169
# Word: 'context' --> Token: 1170
# Word: 'urgent' --> Token: 1171
# Word: 'combin' --> Token: 1172
# Word: 'children.' --> Token: 1173
# Word: 'aid' --> Token: 1174
# Word: 'assign' --> Token: 1175
# Word: 'shower' --> Token: 1176
# Word: 'money' --> Token: 1177
# Word: 'expens' --> Token: 1178
# Word: 'co' --> Token: 1179
# Word: 'load' --> Token: 1180
# Word: 'watch' --> Token: 1181
# Word: 'business' --> Token: 1182
# Word: 'mouth.' --> Token: 1183
# Word: 'achiev' --> Token: 1184
# Word: 'enhanc' --> Token: 1185
# Word: 'crisi' --> Token: 1186
# Word: 'family' --> Token: 1187
# Word: 'guidance' --> Token: 1188
# Word: 'measure.' --> Token: 1189
# Word: 'harm' --> Token: 1190
# Word: 'disembark' --> Token: 1191
# Word: '111' --> Token: 1192
# Word: 'element' --> Token: 1193
# Word: 'hse' --> Token: 1194
# Word: '1.6666666667' --> Token: 1195
# Word: 'flight' --> Token: 1196
# Word: 'nurs' --> Token: 1197
# Word: 'measures' --> Token: 1198
# Word: 'you’v' --> Token: 1199
# Word: '3.1666666667' --> Token: 1200
# Word: 'fair' --> Token: 1201
# Word: 'breathing' --> Token: 1202
# Word: 'hcp' --> Token: 1203
# Word: 'emot' --> Token: 1204
# Word: 'third' --> Token: 1205
# Word: 'minut' --> Token: 1206
# Word: 'qualiti' --> Token: 1207
# Word: 'camp' --> Token: 1208
# Word: '1.25' --> Token: 1209
# Word: 'fluid' --> Token: 1210
# Word: 'movement' --> Token: 1211
# Word: 'staff.' --> Token: 1212
# Word: 'activities' --> Token: 1213
# Word: 'adequ' --> Token: 1214
# Word: 'definit' --> Token: 1215
# Word: 'transmission.' --> Token: 1216
# Word: 'game' --> Token: 1217
# Word: 'grade' --> Token: 1218
# Word: 'academi' --> Token: 1219
# Word: 'cultur' --> Token: 1220
# Word: 'required.' --> Token: 1221
# Word: 'person’' --> Token: 1222
# Word: 'pilot' --> Token: 1223
# Word: 'priorit' --> Token: 1224
# Word: 'american' --> Token: 1225
# Word: 'victim' --> Token: 1226
# Word: 'phonic' --> Token: 1227
# Word: 'retail' --> Token: 1228
# Word: 'econom' --> Token: 1229
# Word: 'listen' --> Token: 1230
# Word: 'latest' --> Token: 1231
# Word: 'categori' --> Token: 1232
# Word: 'guidelines.' --> Token: 1233
# Word: 'violenc' --> Token: 1234
# Word: 'six' --> Token: 1235
# Word: 'flu' --> Token: 1236
# Word: 'groups' --> Token: 1237
# Word: 'handwashing' --> Token: 1238
# Word: 'bridg' --> Token: 1239
# Word: '28' --> Token: 1240
# Word: 'serious' --> Token: 1241
# Word: 'compar' --> Token: 1242
# Word: 'deal' --> Token: 1243
# Word: 'tim' --> Token: 1244
# Word: 'mainli' --> Token: 1245
# Word: 'whose' --> Token: 1246
# Word: 'leader' --> Token: 1247
# Word: 'technolog' --> Token: 1248
# Word: 'arrangements.' --> Token: 1249
# Word: 'interest' --> Token: 1250
# Word: 'currently' --> Token: 1251
# Word: '1.8333333333' --> Token: 1252
# Word: 'dirti' --> Token: 1253
# Word: 'site.' --> Token: 1254
# Word: 'occup' --> Token: 1255
# Word: 'wildlif' --> Token: 1256
# Word: 'household.' --> Token: 1257
# Word: 'readi' --> Token: 1258
# Word: 'suspend' --> Token: 1259
# Word: 'beyond' --> Token: 1260
# Word: 'service' --> Token: 1261
# Word: 'can.' --> Token: 1262
# Word: 'walk' --> Token: 1263
# Word: 'examin' --> Token: 1264
# Word: 'sens' --> Token: 1265
# Word: 'used.' --> Token: 1266
# Word: 'swab' --> Token: 1267
# Word: 'practices.' --> Token: 1268
# Word: 'mark' --> Token: 1269
# Word: 'biosafeti' --> Token: 1270
# Word: 'retent' --> Token: 1271
# Word: '2.1' --> Token: 1272
# Word: 'track' --> Token: 1273
# Word: 'prioritis' --> Token: 1274
# Word: 'drink' --> Token: 1275
# Word: 'hands' --> Token: 1276
# Word: 'insid' --> Token: 1277
# Word: 'premis' --> Token: 1278
# Word: 'diagnost' --> Token: 1279
# Word: 'drop' --> Token: 1280
# Word: 'bag' --> Token: 1281
# Word: 'mass' --> Token: 1282
# Word: 'attende' --> Token: 1283
# Word: 'sneezes' --> Token: 1284
# Word: 'budget' --> Token: 1285
# Word: 'market' --> Token: 1286
# Word: 'specifi' --> Token: 1287
# Word: 'along' --> Token: 1288
# Word: 'throat' --> Token: 1289
# Word: 'hard' --> Token: 1290
# Word: 'government’' --> Token: 1291
# Word: 'unnecessari' --> Token: 1292
# Word: 'els' --> Token: 1293
# Word: 'basi' --> Token: 1294
# Word: 'cold' --> Token: 1295
# Word: 'infrastructur' --> Token: 1296
# Word: 'advice.' --> Token: 1297
# Word: 'hygiene.' --> Token: 1298
# Word: 'touching' --> Token: 1299
# Word: 'fda' --> Token: 1300
# Word: 'northern' --> Token: 1301
# Word: 'opportun' --> Token: 1302
# Word: 'fortnight' --> Token: 1303
# Word: 'safer' --> Token: 1304
# Word: 'capac' --> Token: 1305
# Word: 'origin' --> Token: 1306
# Word: 'patients' --> Token: 1307
# Word: 'visual' --> Token: 1308
# Word: 'etc.' --> Token: 1309
# Word: 'reli' --> Token: 1310
# Word: 'covid19' --> Token: 1311
# Word: 'person.' --> Token: 1312
# Word: 'drive' --> Token: 1313
# Word: 'sheet' --> Token: 1314
# Word: 'english' --> Token: 1315
# Word: 'attent' --> Token: 1316
# Word: 'undergo' --> Token: 1317
# Word: 'reach' --> Token: 1318
# Word: 'hotel' --> Token: 1319
# Word: 'popul' --> Token: 1320
# Word: 'disrupt' --> Token: 1321
# Word: '29' --> Token: 1322
# Word: 'assessment.' --> Token: 1323
# Word: 'niosh' --> Token: 1324
# Word: 'commonli' --> Token: 1325
# Word: 'learning' --> Token: 1326
# Word: 'seeker' --> Token: 1327
# Word: 'supplement' --> Token: 1328
# Word: 'country' --> Token: 1329
# Word: 'monday' --> Token: 1330
# Word: 'did' --> Token: 1331
# Word: 'promot' --> Token: 1332
# Word: 'chemic' --> Token: 1333
# Word: 'plan.' --> Token: 1334
# Word: 'obtain' --> Token: 1335
# Word: 'recov' --> Token: 1336
# Word: 'products.' --> Token: 1337
# Word: 'closed' --> Token: 1338
# Word: 'diagnos' --> Token: 1339
# Word: 'pair' --> Token: 1340
# Word: 'main' --> Token: 1341
# Word: 'u.s.' --> Token: 1342
# Word: 'e' --> Token: 1343
# Word: 'host' --> Token: 1344
# Word: 'supplier' --> Token: 1345
# Word: 'placement' --> Token: 1346
# Word: 'exit' --> Token: 1347
# Word: 'closur' --> Token: 1348
# Word: 'officials.' --> Token: 1349
# Word: 'secondari' --> Token: 1350
# Word: 'rental' --> Token: 1351
# Word: 'inhal' --> Token: 1352
# Word: 'station' --> Token: 1353
# Word: 'merchandis' --> Token: 1354
# Word: 'adher' --> Token: 1355
# Word: 'this.' --> Token: 1356
# Word: 'isolation.' --> Token: 1357
# Word: 'friends' --> Token: 1358
# Word: 'again' --> Token: 1359
# Word: 'd' --> Token: 1360
# Word: 'newborn' --> Token: 1361
# Word: 'vehicles' --> Token: 1362
# Word: '13' --> Token: 1363
# Word: 'country.' --> Token: 1364
# Word: 'detent' --> Token: 1365
# Word: 'messag' --> Token: 1366
# Word: 'times.' --> Token: 1367
# Word: 'disinfection.' --> Token: 1368
# Word: 'closed.' --> Token: 1369
# Word: 'equal' --> Token: 1370
# Word: 'weaken' --> Token: 1371
# Word: 'exhal' --> Token: 1372
# Word: 'pathogen' --> Token: 1373
# Word: 'hazard' --> Token: 1374
# Word: 'setting' --> Token: 1375
# Word: 'summer' --> Token: 1376
# Word: '7.1' --> Token: 1377
# Word: 'coordin' --> Token: 1378
# Word: 'doctor.' --> Token: 1379
# Word: 'aborigin' --> Token: 1380
# Word: 'sleep' --> Token: 1381
# Word: 'maximum' --> Token: 1382
# Word: 'dilut' --> Token: 1383
# Word: 'restart' --> Token: 1384
# Word: 'wider' --> Token: 1385
# Word: 'island' --> Token: 1386
# Word: 'tool' --> Token: 1387
# Word: 'referr' --> Token: 1388
# Word: 'council' --> Token: 1389
# Word: 'advice' --> Token: 1390
# Word: 'i.e.' --> Token: 1391
# Word: 'absenc' --> Token: 1392
# Word: 'response.' --> Token: 1393
# Word: 'relax' --> Token: 1394
# Word: 'danger' --> Token: 1395
# Word: 'procedures' --> Token: 1396
# Word: 'trip' --> Token: 1397
# Word: 'pose' --> Token: 1398
# Word: 'endors' --> Token: 1399
# Word: 'prescrib' --> Token: 1400
# Word: 'specialist' --> Token: 1401
# Word: 'kind' --> Token: 1402
# Word: 'club' --> Token: 1403
# Word: 'previou' --> Token: 1404
# Word: '2.3' --> Token: 1405
# Word: 'health.' --> Token: 1406
# Word: 'remedi' --> Token: 1407
# Word: 'serv' --> Token: 1408
# Word: 'tribal' --> Token: 1409
# Word: 'skin' --> Token: 1410
# Word: 'pack' --> Token: 1411
# Word: '5.2' --> Token: 1412
# Word: '5.3' --> Token: 1413
# Word: '3.125' --> Token: 1414
# Word: 'actual' --> Token: 1415
# Word: 'supervis' --> Token: 1416
# Word: 'distribut' --> Token: 1417
# Word: 'entranc' --> Token: 1418
# Word: 'tables' --> Token: 1419
# Word: 'safety.' --> Token: 1420
# Word: 'land' --> Token: 1421
# Word: 'matern' --> Token: 1422
# Word: 'department.' --> Token: 1423
# Word: 'valu' --> Token: 1424
# Word: 'commit' --> Token: 1425
# Word: 'water.' --> Token: 1426
# Word: 'turn' --> Token: 1427
# Word: 'people’' --> Token: 1428
# Word: 'mother' --> Token: 1429
# Word: 'vulnerable’' --> Token: 1430
# Word: 'leisur' --> Token: 1431
# Word: 'provider' --> Token: 1432
# Word: 'troubl' --> Token: 1433
# Word: '1800' --> Token: 1434
# Word: '3.3333333333' --> Token: 1435
# Word: 'floor' --> Token: 1436
# Word: 'diseases' --> Token: 1437
# Word: 'draw' --> Token: 1438
# Word: 'art' --> Token: 1439
# Word: 'myself' --> Token: 1440
# Word: 'seat' --> Token: 1441
# Word: 'typic' --> Token: 1442
# Word: 'intens' --> Token: 1443
# Word: 'before' --> Token: 1444
# Word: 'instructions.' --> Token: 1445
# Word: 'trash' --> Token: 1446
# Word: '5.1' --> Token: 1447
# Word: '2021' --> Token: 1448
# Word: 'purchas' --> Token: 1449
# Word: 'dedic' --> Token: 1450
# Word: 'old' --> Token: 1451
# Word: 'protocol' --> Token: 1452
# Word: 'welfar' --> Token: 1453
# Word: 'write' --> Token: 1454
# Word: 'million' --> Token: 1455
# Word: '2.625' --> Token: 1456
# Word: 'resources.' --> Token: 1457
# Word: 'princip' --> Token: 1458
# Word: 'framework' --> Token: 1459
# Word: 'cleaning' --> Token: 1460
# Word: 'tradit' --> Token: 1461
# Word: 'previous' --> Token: 1462
# Word: 'throw' --> Token: 1463
# Word: 'contribut' --> Token: 1464
# Word: '2.875' --> Token: 1465
# Word: 'fall' --> Token: 1466
# Word: 'modifi' --> Token: 1467
# Word: 'collabor' --> Token: 1468
# Word: 'larger' --> Token: 1469
# Word: 'covering' --> Token: 1470
# Word: 'stigma' --> Token: 1471
# Word: 'union' --> Token: 1472
# Word: '999' --> Token: 1473
# Word: 'head' --> Token: 1474
# Word: 'anxieti' --> Token: 1475
# Word: 'departments.' --> Token: 1476
# Word: 'shown' --> Token: 1477
# Word: 'express' --> Token: 1478
# Word: 'influenza' --> Token: 1479
# Word: 'eas' --> Token: 1480
# Word: 'nearbi' --> Token: 1481
# Word: 'precautionari' --> Token: 1482
# Word: 'safe.' --> Token: 1483
# Word: 'told' --> Token: 1484
# Word: 'focu' --> Token: 1485
# Word: 'occur' --> Token: 1486
# Word: 'poster' --> Token: 1487
# Word: 'pregnanc' --> Token: 1488
# Word: 'natur' --> Token: 1489
# Word: 'resources' --> Token: 1490
# Word: 'revis' --> Token: 1491
# Word: 'substanti' --> Token: 1492
# Word: 'exposure.' --> Token: 1493
# Word: 'spreads' --> Token: 1494
# Word: 'real' --> Token: 1495
# Word: 'answer' --> Token: 1496
# Word: 'cent' --> Token: 1497
# Word: 'hom' --> Token: 1498
# Word: 'behalf' --> Token: 1499
# Word: 'commiss' --> Token: 1500
# Word: 'requirements.' --> Token: 1501
# Word: 'disadvantag' --> Token: 1502
# Word: 'investig' --> Token: 1503
# Word: 'behaviour' --> Token: 1504
# Word: 'too' --> Token: 1505
# Word: 'regularly' --> Token: 1506
# Word: 'dog' --> Token: 1507
# Word: 'surface.' --> Token: 1508
# Word: 'animals' --> Token: 1509
# Word: 'kit' --> Token: 1510
# Word: 'goods' --> Token: 1511
# Word: 'traineeship' --> Token: 1512
# Word: 'whm' --> Token: 1513
# Word: '31' --> Token: 1514
# Word: 'bill' --> Token: 1515
# Word: 'below.' --> Token: 1516
# Word: 'page' --> Token: 1517
# Word: 'telephon' --> Token: 1518
# Word: 'lot' --> Token: 1519
# Word: 'fill' --> Token: 1520
# Word: 'februari' --> Token: 1521
# Word: 'amend' --> Token: 1522
# Word: 'shortag' --> Token: 1523
# Word: 'provider’' --> Token: 1524
# Word: 'elimin' --> Token: 1525
# Word: 'testing.' --> Token: 1526
# Word: 'emergency' --> Token: 1527
# Word: 'therefore' --> Token: 1528
# Word: 'mix' --> Token: 1529
# Word: 'mainten' --> Token: 1530
# Word: 'prolong' --> Token: 1531
# Word: 'lesson' --> Token: 1532
# Word: '7.3' --> Token: 1533
# Word: 'section.' --> Token: 1534
# Word: '2.125' --> Token: 1535
# Word: 'click' --> Token: 1536
# Word: 'commonwealth' --> Token: 1537
# Word: 'authoris' --> Token: 1538
# Word: 'matter' --> Token: 1539
# Word: 'used' --> Token: 1540
# Word: 'sometim' --> Token: 1541
# Word: 'employees' --> Token: 1542
# Word: 'date.' --> Token: 1543
# Word: 'isolation' --> Token: 1544
# Word: 'rapid' --> Token: 1545
# Word: 'necessary' --> Token: 1546
# Word: '65' --> Token: 1547
# Word: 'plastic' --> Token: 1548
# Word: 'feder' --> Token: 1549
# Word: 'onsit' --> Token: 1550
# Word: 'school.' --> Token: 1551
# Word: 'groups.' --> Token: 1552
# Word: 'vehicles.' --> Token: 1553
# Word: '‘clinic' --> Token: 1554
# Word: 'quickli' --> Token: 1555
# Word: '2.2' --> Token: 1556
# Word: 'payments.' --> Token: 1557
# Word: 'torr' --> Token: 1558
# Word: 'strait' --> Token: 1559
# Word: 'employer.' --> Token: 1560
# Word: 'later' --> Token: 1561
# Word: 'forc' --> Token: 1562
# Word: 'left' --> Token: 1563
# Word: 'plans' --> Token: 1564
# Word: 'coughs' --> Token: 1565
# Word: 'defin' --> Token: 1566
# Word: 'societi' --> Token: 1567
# Word: 'individuals' --> Token: 1568
# Word: 'characterist' --> Token: 1569
# Word: 'adapt' --> Token: 1570
# Word: 'individuals.' --> Token: 1571
# Word: 'environment.' --> Token: 1572
# Word: 'parcel' --> Token: 1573
# Word: 'gain' --> Token: 1574
# Word: '17' --> Token: 1575
# Word: 'bed' --> Token: 1576
# Word: 'global' --> Token: 1577
# Word: 'portabl' --> Token: 1578
# Word: 'kid' --> Token: 1579
# Word: 's' --> Token: 1580
# Word: 'client' --> Token: 1581
# Word: 'test.' --> Token: 1582
# Word: 'imag' --> Token: 1583
# Word: 'award' --> Token: 1584
# Word: 'compromis' --> Token: 1585
# Word: 'disinfection' --> Token: 1586
# Word: 'epa’' --> Token: 1587
# Word: 'sites' --> Token: 1588
# Word: 'activity' --> Token: 1589
# Word: '5.5' --> Token: 1590
# Word: 'automat' --> Token: 1591
# Word: '1.1666666667' --> Token: 1592
# Word: 'mandatori' --> Token: 1593
# Word: 'vari' --> Token: 1594
# Word: 'ato' --> Token: 1595
# Word: 'statement' --> Token: 1596
# Word: 'students' --> Token: 1597
# ...
# Word: 'refectory' --> Token: 11480
# Word: 'vend' --> Token: 11481
# Word: 'machines.' --> Token: 11482
# Word: 'supervision' --> Token: 11483
# Word: 'ehcps.' --> Token: 11484
# Word: 'assessed' --> Token: 11485
# Word: '2.10' --> Token: 11486
# Word: '2.11' --> Token: 11487
# Word: '2.12' --> Token: 11488
# Word: 'classrooms' --> Token: 11489
# Word: '‘step' --> Token: 11490
# Word: 'settings’' --> Token: 11491
# Word: 'noted.' --> Token: 11492
# Word: 'perspect' --> Token: 11493
# Word: 'timetabling' --> Token: 11494
# Word: 'facilitate' --> Token: 11495
# Word: 'campusreduc' --> Token: 11496
# Word: 'coivd' --> Token: 11497
# Word: 'e.g' --> Token: 11498
# Word: '3.7' --> Token: 11499
# Word: 'displayed' --> Token: 11500
# Word: 'subcontractor' --> Token: 11501
# Word: 'etc' --> Token: 11502
# Word: '3.9' --> Token: 11503
# Word: '3.10' --> Token: 11504
# Word: '3.12' --> Token: 11505
# Word: 'unannounc' --> Token: 11506
# Word: 'clin' --> Token: 11507
# Word: 'unstaf' --> Token: 11508
# Word: '4.3' --> Token: 11509
# Word: 'staff’' --> Token: 11510
# Word: '4.4' --> Token: 11511
# Word: '4..6' --> Token: 11512
# Word: 'conform' --> Token: 11513
# Word: '4.7' --> Token: 11514
# Word: 'interact.' --> Token: 11515
# Word: 'searches' --> Token: 11516
# Word: 'presence' --> Token: 11517
# Word: 'exporting' --> Token: 11518
# Word: 'trade.gov.uk' --> Token: 11519
# Word: 'exporters.' --> Token: 11520
# Word: '‘for' --> Token: 11521
# Word: 'me’' --> Token: 11522
# Word: 'baby’s.' --> Token: 11523
# Word: 'actuari' --> Token: 11524
# Word: 'technician' --> Token: 11525
# Word: 'equin' --> Token: 11526
# Word: 'constraints.' --> Token: 11527
# Word: 'flood' --> Token: 11528
# Word: 'remain.' --> Token: 11529
# Word: '‘grab' --> Token: 11530
# Word: 'go’' --> Token: 11531
# Word: 'libraries' --> Token: 11532
# Word: 'arcad' --> Token: 11533
# Word: 'breakfasts' --> Token: 11534
# Word: 'campsites' --> Token: 11535
# Word: 'commercial' --> Token: 11536
# Word: 'introduced.' --> Token: 11537
# Word: 'changing' --> Token: 11538
# Word: 'challenge.' --> Token: 11539
# Word: 'garages' --> Token: 11540
# Word: 'motorway' --> Token: 11541
# Word: 'contactless.' --> Token: 11542
# Word: 'leaving.' --> Token: 11543
# Word: '‘appropriate’.' --> Token: 11544
# Word: '‘appropriate’' --> Token: 11545
# Word: 'appropriate’' --> Token: 11546
# Word: 'quantities.' --> Token: 11547
# Word: '10–30' --> Token: 11548
# Word: 'disappointing' --> Token: 11549
# Word: 'sonograph' --> Token: 11550
# Word: '3.30' --> Token: 11551
# Word: '‘exceptionally' --> Token: 11552
# Word: 'made.’' --> Token: 11553
# Word: 'maintenance.' --> Token: 11554
# Word: 'repetitive.' --> Token: 11555
# Word: 'nature.' --> Token: 11556
# Word: 'gynaecologist' --> Token: 11557
# Word: 'calling' --> Token: 11558
# Word: 'sold' --> Token: 11559
# Word: 'consumer' --> Token: 11560
# Word: 'businesses.it' --> Token: 11561
# Word: 'trading.' --> Token: 11562
# Word: '045' --> Token: 11563
# Word: '£3' --> Token: 11564
# Word: '040' --> Token: 11565
# Word: 'credits' --> Token: 11566
# Word: 'unsuccessful.' --> Token: 11567
# Word: 'majesty'' --> Token: 11568
# Word: 'disclos' --> Token: 11569
# Word: '76' --> Token: 11570
# Word: '83' --> Token: 11571
# Word: 'gestat' --> Token: 11572
# Word: 'emerges' --> Token: 11573
# Word: 'governance.' --> Token: 11574
# Word: 'exiting.' --> Token: 11575
# Word: 'covid19mot' --> Token: 11576
# Word: 'dvsa.gov.uk.' --> Token: 11577
# Word: 'disabled.' --> Token: 11578
# Word: 'nrpf.' --> Token: 11579
# Word: 'reassess' --> Token: 11580
# Word: 'rhlg' --> Token: 11581
# Word: '001' --> Token: 11582
# Word: 'rank' --> Token: 11583
# Word: 'minicab' --> Token: 11584
# Word: 'would.' --> Token: 11585
# Word: 'relationships' --> Token: 11586
# Word: 'fitters' --> Token: 11587
# Word: 'plumbers' --> Token: 11588
# Word: 'momentarili' --> Token: 11589
# Word: 'parad' --> Token: 11590
# Word: 'www.brainparade.com' --> Token: 11591
# Word: 'picture' --> Token: 11592
# Word: 'helpkidzlearn' --> Token: 11593
# Word: 'www.helpkidzlearn.com' --> Token: 11594
# Word: 'www.sensoryapphouse.com' --> Token: 11595
# Word: 'visuals2go' --> Token: 11596
# Word: 'www.visuals2go.com' --> Token: 11597
# Word: 'refug' --> Token: 11598
# Word: '2000' --> Token: 11599
# Word: '247.' --> Token: 11600
# Word: 'refuge’' --> Token: 11601
# Word: 'perpetrator.' --> Token: 11602
# Word: 'bot' --> Token: 11603
# Word: 'laptops.' --> Token: 11604
# Word: 'pink' --> Token: 11605
# Word: 'corner.' --> Token: 11606
# Word: 'irrevoc' --> Token: 11607
# Word: 'ordinated.' --> Token: 11608
# Word: 'luggag' --> Token: 11609
# Word: 'task.' --> Token: 11610
# Word: '“cohorting”' --> Token: 11611
# Word: 'seating' --> Token: 11612
# Word: '‘bench’' --> Token: 11613
# Word: 'style.' --> Token: 11614
# Word: 'parking.' --> Token: 11615
# Word: 'apprenticeships.' --> Token: 11616
# Word: 'receives.' --> Token: 11617
# Word: 'financially' --> Token: 11618
# Word: 'office’' --> Token: 11619
# Word: 'esfa.ppn220queries' --> Token: 11620
# Word: 'education.gov.uk' --> Token: 11621
# Word: 'officer’' --> Token: 11622
# Word: 'racks.' --> Token: 11623
# Word: 'labs.' --> Token: 11624
# Word: 'bus' --> Token: 11625
# Word: 'tram' --> Token: 11626
# Word: 'ferri' --> Token: 11627
# Word: 'unexpect' --> Token: 11628
# Word: 'quieter' --> Token: 11629
# Word: 'direct.' --> Token: 11630
# Word: 'alight' --> Token: 11631
# Word: 'metres' --> Token: 11632
# Word: 'interchanges.' --> Token: 11633
# Word: 'canopies' --> Token: 11634
# Word: 'private' --> Token: 11635
# Word: 'dockless' --> Token: 11636
# Word: 'trials.' --> Token: 11637
# Word: 'bore' --> Token: 11638
# Word: 'frustrating.' --> Token: 11639
# Word: 'permit.' --> Token: 11640
# Word: 'rebuild' --> Token: 11641
# Word: 'phases.' --> Token: 11642
# Word: 'runners' --> Token: 11643
# Word: 'coaches.' --> Token: 11644
# Word: 'pram' --> Token: 11645
# Word: 'peers' --> Token: 11646
# Word: 'internship.' --> Token: 11647
# Word: 'braill' --> Token: 11648
# Word: 'unanticip' --> Token: 11649
# Word: 'queue.' --> Token: 11650
# Word: 'sweat' --> Token: 11651
# Word: 'panic' --> Token: 11652
# Word: 'flashbacks' --> Token: 11653
# Word: '‘safe' --> Token: 11654
# Word: 'space’' --> Token: 11655
# Word: 'anxious.' --> Token: 11656
# Word: 'deputy' --> Token: 11657
# Word: 'covered.' --> Token: 11658
# Word: 'insurance.' --> Token: 11659
# Word: 'abi' --> Token: 11660
# Word: 'nowher' --> Token: 11661
# Word: 'army' --> Token: 11662
# Word: 'layouts' --> Token: 11663
# Word: 'requests' --> Token: 11664
# Word: 'www.activelearnprimary.co.uk' --> Token: 11665
# Word: 'dyslexia' --> Token: 11666
# Word: 'literacy.' --> Token: 11667
# Word: '11160' --> Token: 11668
# Word: 'colleges.pdf' --> Token: 11669
# Word: 'charl' --> Token: 11670
# Word: 'dicken' --> Token: 11671
# Word: 'www.charlesdickens.southwark.sch.uk' --> Token: 11672
# Word: 'jenni' --> Token: 11673
# Word: 'wren' --> Token: 11674
# Word: 'makaton' --> Token: 11675
# Word: 'do2learn' --> Token: 11676
# Word: 'usa' --> Token: 11677
# Word: 'do2learn.com' --> Token: 11678
# Word: 'theme.' --> Token: 11679
# Word: 'song' --> Token: 11680
# Word: 'inclusiveteach.com' --> Token: 11681
# Word: 'printable' --> Token: 11682
# Word: 'slcn' --> Token: 11683
# Word: 'mld' --> Token: 11684
# Word: 'themat' --> Token: 11685
# Word: 'www.nicurriculum.org.uk' --> Token: 11686
# Word: 'microsite' --> Token: 11687
# Word: 'thematic' --> Token: 11688
# Word: 'index.asp' --> Token: 11689
# Word: 'pmld.' --> Token: 11690
# Word: 'offered.' --> Token: 11691
# Word: 'priori' --> Token: 11692
# Word: 'wood' --> Token: 11693
# Word: 'www.priorywoods.middlesbrough.sch.uk' --> Token: 11694
# Word: 'title' --> Token: 11695
# Word: 'pid' --> Token: 11696
# Word: 'winning' --> Token: 11697
# Word: 'outstand' --> Token: 11698
# Word: 'programmes.' --> Token: 11699
# Word: 'www.parentseveningsystem.co.uk' --> Token: 11700
# Word: 'features' --> Token: 11701
# Word: 'meetings.asp' --> Token: 11702
# Word: 'www.sendgateway.org.uk' --> Token: 11703
# Word: 'wss' --> Token: 11704
# Word: 'nqt' --> Token: 11705
# Word: 'videos.html' --> Token: 11706
# Word: 'www.ianbean.co.uk' --> Token: 11707
# Word: 'www.senteacher.org' --> Token: 11708
# Word: 'www.speechandlanguagekids.com' --> Token: 11709
# Word: 'podcast' --> Token: 11710
# Word: 'itun' --> Token: 11711
# Word: 'multimedia' --> Token: 11712
# Word: 'speechandlanguage.info' --> Token: 11713
# Word: 'www.teachingvisuallyimpaired.com' --> Token: 11714
# Word: 'blind' --> Token: 11715
# Word: 'www.theautismpage.com' --> Token: 11716
# Word: 'ucl' --> Token: 11717
# Word: 'www.ucl.ac.uk' --> Token: 11718
# Word: 'ioe' --> Token: 11719
# Word: 'homeschooling' --> Token: 11720
# Word: 'managing' --> Token: 11721
# Word: 'year’' --> Token: 11722
# Word: 'ran' --> Token: 11723
# Word: 'refocu' --> Token: 11724
# Word: 'reintroduc' --> Token: 11725
# Word: 'learners’' --> Token: 11726
# Word: 'competence.' --> Token: 11727
# Word: 'demonstration.' --> Token: 11728
# Word: 'ite' --> Token: 11729
# Word: '£18' --> Token: 11730
# Word: 'standard.' --> Token: 11731
# Word: 'aoc.co.uk.' --> Token: 11732
# Word: 'collat' --> Token: 11733
# Word: 'holex' --> Token: 11734
# Word: 'natspec' --> Token: 11735
# Word: 'besa’' --> Token: 11736
# Word: 'besa' --> Token: 11737
# Word: 'boards.' --> Token: 11738
# Word: 'thes' --> Token: 11739
# Word: 'registration.' --> Token: 11740
# Word: 'safeguarding' --> Token: 11741
# Word: 'rates.' --> Token: 11742
# Word: 'secondli' --> Token: 11743
# Word: 'basics' --> Token: 11744
# Word: 'writing' --> Token: 11745
# Word: 'socialis' --> Token: 11746
# Word: 'peers.' --> Token: 11747
# Word: 'immens' --> Token: 11748
# Word: 'ready.' --> Token: 11749
# Word: 'setting’' --> Token: 11750
# Word: 'realloc' --> Token: 11751
# Word: 'ramp' --> Token: 11752
# Word: '‘essential’.' --> Token: 11753
# Word: 'thursday' --> Token: 11754
# Word: 'claimant’' --> Token: 11755
# Word: 'goals.' --> Token: 11756
# Word: 'ask.' --> Token: 11757
# Word: 'catalogu' --> Token: 11758
# Word: 'receiving' --> Token: 11759
# Word: 'experienced' --> Token: 11760
# Word: 'sencos' --> Token: 11761
# Word: 'impairments' --> Token: 11762
# Word: 'knowledge.' --> Token: 11763
# Word: 'reconfirmation' --> Token: 11764
# Word: 'workersm' --> Token: 11765
# Word: 'codes' --> Token: 11766
# Word: 'morning.' --> Token: 11767
# Word: 'advice.if' --> Token: 11768
# Word: 'fitting' --> Token: 11769
# Word: 'accessible.' --> Token: 11770
# Word: 'patterns.' --> Token: 11771
# Word: 'whiteboards' --> Token: 11772
# Word: 'workspaces.' --> Token: 11773
# Word: 'bulkhead' --> Token: 11774
# Word: 'follow.' --> Token: 11775
# Word: 'mandatory.' --> Token: 11776
# Word: 'create.' --> Token: 11777
# Word: '4104' --> Token: 11778
# Word: 'safel' --> Token: 11779
# Word: 'stronger' --> Token: 11780
# Word: 'holist' --> Token: 11781
# Word: '07970' --> Token: 11782
# Word: '350366' --> Token: 11783
# Word: '3947' --> Token: 11784
# Word: '2601' --> Token: 11785
# Word: 'da' --> Token: 11786
# Word: 'signhealth.org.uk' --> Token: 11787
# Word: 'nhs.' --> Token: 11788
# Word: 'fourteen' --> Token: 11789
# Word: 'centrally' --> Token: 11790
# Word: 'holidays.' --> Token: 11791
# Word: 'positive.' --> Token: 11792
# Word: 'finalis' --> Token: 11793
# Word: 'then.' --> Token: 11794
# Word: 'overpaid' --> Token: 11795
# Word: 'overpay' --> Token: 11796
# Word: 'overpayment.' --> Token: 11797
# Word: 'tracheal' --> Token: 11798
# Word: 'cite' --> Token: 11799
# Word: 'conven' --> Token: 11800
# Word: 'undiagnosed.' --> Token: 11801
# Word: 'learnt' --> Token: 11802
# Word: 'managed' --> Token: 11803
# Word: 'ra' --> Token: 11804
# Word: 'tandem' --> Token: 11805
# Word: 'hospitalization' --> Token: 11806
# Word: 'intensified.' --> Token: 11807
# Word: 'transgend' --> Token: 11808
# Word: 'methadon' --> Token: 11809
# Word: 'buprenorphin' --> Token: 11810
# Word: 'ennds' --> Token: 11811
# Word: 'disorders.' --> Token: 11812
# Word: 'evolut' --> Token: 11813
# Word: 'perpetr' --> Token: 11814
# Word: 'screens.' --> Token: 11815
# Word: 'stairs' --> Token: 11816
# Word: 'diary' --> Token: 11817
# Word: 'motivation.' --> Token: 11818
# Word: 'www.euro.who.int' --> Token: 11819
# Word: 'topics' --> Token: 11820
# Word: 'recache' --> Token: 11821
# Word: 'fbclid' --> Token: 11822
# Word: 'iwar2rqyvybnmpdcmjbwqmoz0hzxzmit' --> Token: 11823
# Word: '9ykzxu6zhjgnywrtezwouqefu8v0' --> Token: 11824
# Word: '‘tummi' --> Token: 11825
# Word: 'invent' --> Token: 11826
# Word: 'throwing' --> Token: 11827
# Word: 'catching' --> Token: 11828
# Word: 'kicking' --> Token: 11829
# Word: 'postur' --> Token: 11830
# Word: 'jumping.' --> Token: 11831
# Word: 'juggle.' --> Token: 11832
# Word: 'climb' --> Token: 11833
# Word: 'squats.' --> Token: 11834
# Word: 'zones' --> Token: 11835
# Word: 'symptomatology' --> Token: 11836
# Word: 'availability' --> Token: 11837
# Word: 'officials' --> Token: 11838
# Word: 'rehears' --> Token: 11839
# Word: 'sports.' --> Token: 11840
# Word: 'colleague' --> Token: 11841
# Word: 'mortem' --> Token: 11842
# Word: 'learnhow' --> Token: 11843
# Word: 'andfor' --> Token: 11844
# Word: 'front.' --> Token: 11845
# Word: 'isten' --> Token: 11846
# Word: 'closely' --> Token: 11847
# Word: 'empathi' --> Token: 11848
# Word: 'nquir' --> Token: 11849
# Word: 'alid' --> Token: 11850
# Word: 'experiences.' --> Token: 11851
# Word: 'nhanc' --> Token: 11852
# Word: 'upport' --> Token: 11853
# Word: 'multiply.' --> Token: 11854
# Word: 'promoting' --> Token: 11855
# Word: 'ethyl' --> Token: 11856
# Word: 'thermometers' --> Token: 11857
# Word: '5000ppm' --> Token: 11858
# Word: 'heat.' --> Token: 11859
# Word: 'ment' --> Token: 11860
# Word: 'oili' --> Token: 11861
# Word: 'dissolv' --> Token: 11862
# Word: 'donors.' --> Token: 11863
# Word: 'physicians' --> Token: 11864
# Word: 'pulmonolog' --> Token: 11865
# Word: 'elearning.' --> Token: 11866
# Word: 'noncommunic' --> Token: 11867
# Word: 'recovered' --> Token: 11868
# Word: 'hypertension.' --> Token: 11869
# Word: 'plhiv' --> Token: 11870
# Word: 'addict' --> Token: 11871
# Word: 'ensured.' --> Token: 11872
# Word: 'presentation.' --> Token: 11873
# Word: 'fomites.' --> Token: 11874
# Word: 'shopper' --> Token: 11875
# Word: 'gmp' --> Token: 11876
# Word: 'ghp' --> Token: 11877
# Word: 'market.' --> Token: 11878
# Word: 'markets.' --> Token: 11879
# Word: 'prevalent' --> Token: 11880
# Word: 'kingdom' --> Token: 11881
# Word: 'wat' --> Token: 11882
# Word: 'teleworking' --> Token: 11883
# Word: 'supply.' --> Token: 11884
# Word: 'intact' --> Token: 11885
# Word: 'fumig' --> Token: 11886
# Word: 'noxiou' --> Token: 11887
# Word: 'ineffect' --> Token: 11888
# Word: 'unpav' --> Token: 11889
# Word: 'walkways.' --> Token: 11890
# Word: 'exercise.' --> Token: 11891
# Word: 'tai' --> Token: 11892
# Word: 'chi' --> Token: 11893
# Word: 'hydrated' --> Token: 11894
# Word: 'disturb' --> Token: 11895
# Word: 'falls' --> Token: 11896
# Word: 'despair.' --> Token: 11897
# Word: 'crosswords' --> Token: 11898
# Word: 'sudoku' --> Token: 11899
# Word: 'worrying.' --> Token: 11900
# Word: 'psychosoci' --> Token: 11901
# Word: 'story' --> Token: 11902
# Word: 'en.unesco.org' --> Token: 11903
# Word: 'educationresponse' --> Token: 11904
# Word: 'keeping' --> Token: 11905
# Word: 'exists.' --> Token: 11906
# Word: 'resolve.' --> Token: 11907
# Word: 'wellness.' --> Token: 11908
# Word: '‘fit' --> Token: 11909
# Word: 'work’' --> Token: 11910
# Word: 'ebola' --> Token: 11911
# Word: 'guinea' --> Token: 11912
# Word: 'liberia' --> Token: 11913
# Word: 'sierra' --> Token: 11914
# Word: 'leone' --> Token: 11915
# Word: 'massiv' --> Token: 11916
# Word: 'saharan' --> Token: 11917
# Word: 'insecticide' --> Token: 11918
# Word: 'tr' --> Token: 11919
# Word: 'regions' --> Token: 11920
# Word: 'blackmail' --> Token: 11921
# Word: 'humiliation.' --> Token: 11922
# Word: 'predat' --> Token: 11923
# Word: 'webcam' --> Token: 11924
# Word: 'bedroom.' --> Token: 11925
# Word: 'hurtful' --> Token: 11926
# Word: 'discriminatori' --> Token: 11927
# Word: 'www.unicef.org' --> Token: 11928
# Word: '67396' --> Token: 11929
# Word: '20and' --> Token: 11930
# Word: '20its' --> Token: 11931
# Word: '20implications' --> Token: 11932
# Word: '20for' --> Token: 11933
# Word: '20protecting' --> Token: 11934
# Word: '20children' --> Token: 11935
# Word: '20online.pdf' --> Token: 11936
# Word: 'bacil' --> Token: 11937
# Word: 'calmette' --> Token: 11938
# Word: 'guérin' --> Token: 11939
# Word: 'prophylaxi' --> Token: 11940
# Word: 'boring' --> Token: 11941
# Word: 'unlucki' --> Token: 11942
# Word: 'dying.' --> Token: 11943
# Word: 'menstrual' --> Token: 11944
# Word: 'condom' --> Token: 11945
# Word: 'iuds' --> Token: 11946
# Word: 'iuds.' --> Token: 11947

# %%
sequences = tokenizer_all.texts_to_sequences(combined_text)

# %%
print("Sequences:")
print(sequences[:2])
# Out:
# Sequences:
# [[48, 39, 53, 76, 69, 244, 6, 355, 14, 9, 10, 6, 173, 355, 1327, 7, 3387, 30, 929, 1314, 33, 171, 79, 58, 2046, 1168, 2431, 641, 12, 15, 1432, 3, 47, 1, 39, 14, 9, 10, 177, 2152, 79, 5, 355, 1327, 3, 831, 14, 9, 10, 831, 8, 2, 4626, 838, 30, 929, 1314, 33, 171, 79, 58, 15, 172, 3, 2432, 79, 5, 4626, 831, 4626, 831, 301, 241, 686, 14, 9, 10, 6, 160, 136, 436, 12, 3524, 3387, 80, 301, 241, 686, 2047, 33, 79, 58, 126, 2, 57, 1328, 3, 47, 59, 13, 128, 65, 30, 93, 160, 136, 436, 12, 3524, 831, 301, 241, 686, 14, 9, 10, 6, 160, 136, 436, 12, 3524, 1432, 80, 301, 241, 686, 2047, 33, 79, 58, 59, 3524, 831, 65, 2, 57, 2231, 160, 136, 436, 12, 3524, 33, 231, 301, 241, 686, 7576, 160, 3525, 5573, 384, 958], [48, 39, 53, 76, 69, 244, 6, 355, 14, 9, 10, 6, 173, 355, 1327, 7, 3387, 30, 929, 1314, 33, 171, 79, 58, 2046, 1168, 2431, 641, 12, 15, 1432, 3, 47, 1, 39, 14, 9, 10, 177, 2152, 79, 5, 355, 1327, 3, 831, 14, 9, 10, 831, 8, 2, 4626, 838, 30, 929, 1314, 33, 171, 79, 58, 15, 172, 3, 2432, 79, 5, 4626, 831, 4626, 831, 301, 241, 686, 14, 9, 10, 6, 160, 136, 436, 12, 3524, 3387, 80, 301, 241, 686, 2047, 33, 79, 58, 126, 2, 57, 1328, 3, 47, 59, 13, 128, 65, 30, 93, 160, 136, 436, 12, 3524, 831, 301, 241, 686, 14, 9, 10, 6, 160, 136, 436, 12, 3524, 1432, 80, 301, 241, 686, 2047, 33, 79, 58, 59, 3524, 831, 65, 2, 57, 2231, 160, 136, 436, 12, 3524, 33, 231, 301, 241, 686, 7576, 160, 3525, 5573, 384, 958]]

# %%
# Assuming 'sequences' is your list of tokenized sequences
# Set the maximum sequence length
# You can set this to the length of the longest sequence or a predefined length
max_sequence_length = max([len(seq) for seq in sequences])

# %%
# Pad the sequences
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding="post")

# %%
print(padded_sequences[:10])
# Out:
# [[ 48  39  53 ...   0   0   0]
#  [ 48  39  53 ...   0   0   0]
#  [ 48  39  53 ...   0   0   0]
#  ...
#  [ 14  53 530 ...   0   0   0]
#  [ 14  53 530 ...   0   0   0]
#  [ 14  53 530 ...   0   0   0]]
